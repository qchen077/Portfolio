# %%
html_content = """
<!doctype html>
<html lang="en">
<head>
<meta charset="utf-8" />
<meta name="viewport" content="width=device-width, initial-scale=1" />
<title>Appendix: Roadway Block Variables Documentation</title>
<style>
  :root{
    --blue:#145da0; --light:#eaf4ff; --ink:#0f172a; --muted:#415575;
    --line:#d7e5f5; --bg:#f4f8fc; --why:#fff4d8; --accent:#f3b300;
  }
  *{box-sizing:border-box}
  body{
    margin:0; background:linear-gradient(90deg,#eef4fa,#fff 12%,#fff 88%,#eef4fa);
    font-family:Arial,Helvetica,sans-serif; color:var(--ink); line-height:1.55; font-size:16px;
  }
  .page{max-width:1160px;margin:0 auto;padding:36px 42px 70px;background:#fff;
        box-shadow:0 0 22px rgba(50,80,120,.08)}
  h1{font-size:34px;line-height:1.18;color:#0d4f93;margin:0 0 26px;border-bottom:3px solid #dcecff;padding-bottom:16px}
  .section{margin:26px 0 38px} /* tightened to remove blank areas */
  h2{font-size:25px;line-height:1.25;color:#145da0;margin:0 0 8px;border-left:5px solid #145da0;padding-left:13px}
  .lead{margin:4px 0 16px;color:var(--muted)}
  p{margin:8px 0 12px}
  ul{margin:8px 0 16px;padding-left:23px}
  li{margin:5px 0}
  .note,.conclusion{
    background:#f8fbff;border:1px solid var(--line);border-radius:12px;padding:14px 16px;margin:16px 0
  }
  table{width:100%;border-collapse:collapse;margin:14px 0 18px}
  th,td{border:1px solid var(--line);padding:9px 10px;text-align:left}
  th{background:var(--light);color:#145da0}
  /* Image cards & side-by-side grid */
  .figure-grid{display:grid;grid-template-columns:repeat(auto-fit,minmax(260px,1fr));gap:14px;align-items:start}
  .image-card{border:1px solid var(--line);border-radius:12px;padding:10px;background:#fff;box-shadow:0 6px 18px rgba(35,70,110,.06);overflow:hidden}
  .image-card img{display:block;width:100%;height:360px;object-fit:cover;object-position:center;border-radius:8px}
  figcaption{font-size:13px;color:#48607d;text-align:center;margin-top:8px}
  @media (max-width:760px){.page{padding:24px 18px}h1{font-size:28px}h2{font-size:22px}
                            .image-card img{height:auto;max-height:480px;object-fit:contain}}
</style>
</head>
<body>
<main class="page">
  <h1>Appendix: Roadway Block Variables Documentation</h1>
 
  <section class="section">
    <h2>1. Spatial Structure</h2>
    <p class="lead">Road segments are lines; census tracts are polygons. Each road segment is spatially joined to a tract using geometry.</p>
    <ul>
      <li><strong>Census tract</strong> = polygon</li>
      <li><strong>GEOID</strong> = Census tract identifier</li>
      <li><strong>Road segment</strong> = line (LineString)</li>
    </ul>
    <!-- Images: side-by-side example (replace src with your images/base64) -->
    <div class="figure-grid">
      <figure class="image-card">
        <!-- TODO: drop actual image data or path -->
        placeholder.png
        <figcaption>Spatial join: segment to tract</figcaption>
      </figure>
      <figure class="image-card">
        placeholder.png
        <figcaption>Geometry overview</figcaption>
      </figure>
    </div>
  </section>
 
  <section class="section">
    <h2>2. Identification Variables</h2>
    <p class="lead">Unique segment identifiers; <em>SHAPELEN</em> is invalid (dropped). A corrected length (<em>length_m</em>) is computed from geometry for analysis.</p>
    <table>
      <thead><tr><th>Variable</th><th>Description</th><th>Modeling / Analytical Use</th></tr></thead>
      <tbody>
        <tr><td><strong>ROUTEID</strong></td><td>Unique segment identifier</td><td>Joins/validation; not used directly in modeling</td></tr>
        <tr><td><strong>SHAPELEN</strong></td><td>Original segment length field</td><td>Dropped (values are 0/invalid)</td></tr>
        <tr><td><strong>length_m</strong></td><td>Corrected segment length in meters (projected to EPSG:3857)</td><td>Valid measure for aggregation, exposure normalization, density metrics</td></tr>
      </tbody>
    </table>
  </section>
 
  <section class="section">
    <h2>3. Traffic Exposure</h2>
    <p class="lead">AADT and truck composition are primary drivers of crash opportunity. AADT is modeled, so may introduce estimation bias.</p>
    <ul>
      <li><strong>AADT</strong>: Average daily traffic volume</li>
      <li><strong>AADT_COMBINATION</strong>: Heavy trucks (tractor‑trailers)</li>
      <li><strong>AADT_SINGLE_UNIT</strong>: Medium trucks, delivery, buses</li>
    </ul>
  </section>
 
  <section class="section">
    <h2>4. Road Geometry</h2>
    <ul>
      <li><strong>TOTALTRAVELLANES</strong>: total lane count</li>
      <li><strong>TOTALTRAVELLANEWIDTH</strong>: lane width (ft)</li>
      <li><strong>TOTALCROSSSECTIONWIDTH</strong>: cross‑section width (ft)</li>
      <li><strong>INBOUND / OUTBOUND lanes</strong>: directional lanes</li>
    </ul>
    <div class="note">Higher speeds & more complex interactions increase crash risk.</div>
  </section>
 
  <section class="section">
    <h2>5. Parking Infrastructure</h2>
    <ul>
      <li><strong>TOTALPARKINGLANES</strong></li>
      <li><strong>TOTALPARKINGLANEWIDTH</strong> (ft)</li>
    </ul>
    <div class="note">On‑street parking can obstruct visibility, increase turning conflicts, and create dooring risks.</div>
  </section>
 
  <section class="section">
    <h2>6. Bike & Buffer</h2>
    <ul>
      <li><strong>TOTALBIKELANES</strong> / <strong>TOTALBIKELANEWIDTH</strong> (ft)</li>
      <li><strong>TOTALRAISEDBUFFERS</strong> / <strong>TOTALRAISEDBUFFERWIDTH</strong> (ft)</li>
    </ul>
    <div class="note">Buffers support cyclist safety via physical separation and improved mode clarity.</div>
  </section>
 
  <section class="section">
    <h2>7. Pavement</h2>
    <ul>
      <li><strong>PCI_SCORE</strong> (0–100): overall condition</li>
      <li><strong>IRI</strong>: surface roughness (m/km; partial coverage)</li>
      <li><strong>SURFACE_TYPE</strong>: asphalt, concrete, brick, gravel</li>
    </ul>
  </section>
 
  <section class="section">
    <h2>8. Traffic Calming</h2>
    <p><strong>VERTICAL_DEFLECTION</strong>: speed bumps/humps/raised tables indicator</p>
  </section>
 
  <section class="section">
    <h2>9. Sidewalks</h2>
    <ul>
      <li><strong>SIDEWALK_IB_WIDTH / OB_WIDTH</strong> (ft)</li>
      <li><strong>SIDEWALK_IB_PAVTYPE / OB_PAVTYPE</strong></li>
    </ul>
  </section>
 
  <section class="section">
    <h2>10. Bus Lanes</h2>
    <ul>
      <li><strong>BUSLANE_INBOUND</strong></li>
      <li><strong>BUSLANE_OUTBOUND</strong></li>
    </ul>
  </section>
 
  <section class="section">
    <h2>11. Speed Limits</h2>
    <ul>
      <li><strong>SPEEDLIMITS_OB</strong> (mph)</li>
      <li><em>SPEEDLIMITS_IB</em> not available</li>
    </ul>
  </section>
 
  <section class="section">
    <h2>12. FHWA Functional Class</h2>
    <table>
      <thead><tr><th>Code</th><th>Classification</th></tr></thead>
      <tbody>
        <tr><td>1</td><td>Interstate</td></tr>
        <tr><td>2</td><td>Principal Arterial – Other Freeways/Expressways</td></tr>
        <tr><td>3</td><td>Principal Arterial – Other</td></tr>
        <tr><td>4</td><td>Minor Arterial</td></tr>
        <tr><td>5</td><td>Major Collector</td></tr>
        <tr><td>6</td><td>Minor Collector</td></tr>
        <tr><td>7</td><td>Local</td></tr>
      </tbody>
    </table>
  </section>
 
  <section class="section">
    <h2>13. DC Functional Class</h2>
    <table>
      <thead><tr><th>Code</th><th>Classification</th></tr></thead>
      <tbody>
        <tr><td>11</td><td>Interstate</td></tr>
        <tr><td>12</td><td>Other Freeway &amp; Expressway</td></tr>
        <tr><td>14</td><td>Principal Arterial</td></tr>
        <tr><td>16</td><td>Minor Arterial</td></tr>
        <tr><td>17</td><td>Major Collector</td></tr>
        <tr><td>18</td><td>Minor Collector</td></tr>
        <tr><td>19</td><td>Local</td></tr>
      </tbody>
    </table>
  </section>
 
  <section class="section">
    <h2>14. Data Limitations & Coverage</h2>
    <ul>
      <li><em>SHAPELEN</em> expected to represent segment length; values are zero → replaced by <strong>length_m</strong>.</li>
      <li>Turn lane length fields often 0/missing → excluded from analysis.</li>
      <li>General data quality issues (excess zeros); additional QA/QC recommended.</li>
    </ul>
    <table>
      <thead><tr><th>Variable Type</th><th>Unit</th></tr></thead>
      <tbody>
        <tr><td>Length / width</td><td>Feet (except <em>length_m</em> in meters)</td></tr>
        <tr><td>Speed</td><td>Miles per hour (mph)</td></tr>
        <tr><td>AADT</td><td>Average daily vehicle counts</td></tr>
      </tbody>
    </table>
    <div class="conclusion">
      <strong>AADT definitions:</strong> Total vehicles; Combination trucks; Single‑unit trucks/buses.
      Values derived from observed counts and modeled to current year. The Open Data timestamp may not auto-refresh.
      Segmentation: street-to-street intersections.
    </div>
  </section>
 
  <!-- Final image row placeholder (keep side-by-side on wide screens) -->
  <section class="section">
    <h2>Appendix Figures (Examples)</h2>
    <div class="figure-grid">
      <figure class="image-card">
        <img src="r.png
        <figcaption>Example A</figcaption>
      </figure>
      <figure class="image-card">
        <img src="placeholder.png" alt="ion>Example B</figcaption>
      </figure>
    </div>
  </section>
 
</main>
</body>
 
"""

with open("/Users/thehoop/ds_projects/Data/road_doc.html", "w", encoding="utf-8") as f:
    f.write(html_content)

# %%
'../../../Data/road_doc.html'
